# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshak02/heart_disease_prediction/blob/main/heart_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import(
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-69f05512-55ae-4f83-88b2-8c0b82fcfc76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69f05512-55ae-4f83-88b2-8c0b82fcfc76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Data Loading & Preprocessing

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load Dataset
df = pd.read_csv("heart.csv")

# Features and Target
X = df.drop("HeartDisease", axis=1)
y = df["HeartDisease"]

# Encoding Categorical Columns
X = pd.get_dummies(X, drop_first=True)

# Scaling
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (918, 15)
# Target Shape: (918,)

# %% [markdown]
# # Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42
)

print("X_train Shape:", X_train.shape)
print("X_test Shape:", X_test.shape)
print("y_train Shape:", y_train.shape)
print("y_test Shape:", y_test.shape)
# Out:
# X_train Shape: (734, 15)
# X_test Shape: (184, 15)
# y_train Shape: (734,)
# y_test Shape: (184,)

# %% [markdown]
# # Building Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)
print("Model Trained Successfully")
# Out:
# Model Trained Successfully

# %% [markdown]
# # Making Predictions

# %%
y_pred = model.predict(X_test)

print("First 10 Actual Values:")
print(y_test.iloc[:10].values)

print("First 10 Predicted Values:")
print(y_pred[:10])
# Out:
# First 10 Actual Values:
# [0 1 1 1 0 1 1 0 1 1]
# First 10 Predicted Values:
# [0 0 1 1 0 1 1 0 1 1]

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

TN, FP, FN, TP = cm.ravel()

print("True Negative (TN):", TN)
print("False Positive (FP):", FP)
print("False Negative (FN):", FN)
print("True Positive (TP):", TP)
# Out:
# Confusion Matrix:
# [[67 10]
#  [17 90]]
# True Negative (TN): 67
# False Positive (FP): 10
# False Negative (FN): 17
# True Positive (TP): 90

# %% [markdown]
# # Model evaluation metrix

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1 Score :", f1)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 0.8532608695652174
# Precision: 0.9
# Recall   : 0.8411214953271028
# F1 Score : 0.8695652173913043
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        77
#            1       0.90      0.84      0.87       107
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %% [markdown]
# # saving models

# %%
joblib.dump(model, "heart_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(X.columns.tolist(), "columns.pkl")

print("Model and columns saved successfully.")
# Out:
# Model and columns saved successfully.
